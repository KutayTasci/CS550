# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

def gini_impurity (value_counts):
    n = value_counts.sum()
    p_sum = 0
    for key in value_counts.keys():
        p_sum = p_sum  +  (value_counts[key] / n ) * (value_counts[key] / n ) 
    gini = 1 - p_sum
    return gini

# %%
class leaf_node:
    def __init__(self, data, labels, gini):
        self.samples = self.set_samples(data)
        self.value = self.set_value(labels)
        self.gini = gini      
        print("leaf_node_created", self.gini, self.samples)
    def set_samples(self, data):
        return len(data)
    def set_value(self, labels):
        ls = labels.unique()
        ls = sorted(ls)
        values = []
        for i in ls:
            temp = len(labels[labels == i])
            values.append(temp)
        return values
class decision_node:
    def __init__(self, data, labels,gini_min = 0):

        self.samples = self.set_samples(data)
        self.value = self.set_value(labels)
        self.gini = self.set_gini(labels)
        self.type = -1
        self.colm, self.split_val = self.generate_split(data, labels)
        print("decision_node created",self.gini)
        rhs_data = data[data[self.colm] < self.split_val]

        rhs_label = labels[data[self.colm] < self.split_val]
        rhs_gini =  gini_impurity(rhs_label.value_counts())
        if (rhs_gini <= gini_min):
            self.right = leaf_node(rhs_data, rhs_label, rhs_gini)
        else:
            self.right = decision_node(rhs_data, rhs_label)
            
        lhs_data = data[data[self.colm] >= self.split_val]

        lhs_label = labels[data[self.colm] >= self.split_val]
        lhs_gini =  gini_impurity(lhs_label.value_counts())
        if (lhs_gini <= gini_min):
            self.left = leaf_node(lhs_data, lhs_label, lhs_gini)
        else:
            self.left = decision_node(lhs_data, lhs_label)
            
    def set_samples(self, data):
        return len(data)
    def set_value(self, labels):
        ls = labels.unique()
        ls = sorted(ls)
        values = []
        for i in ls:
            temp = len(labels[labels == i])
            values.append(temp)
        return values
    def set_gini(self,labels):
        return gini_impurity(labels.value_counts())
    def find_split(self, column, labels):
        if column.dtype != "float64":
            rhs = labels[column < 0.5]
            lhs = labels[column >= 0.5]
            min_gini = gini_impurity(rhs.value_counts()) + gini_impurity(lhs.value_counts())
            return 0.5, min_gini
        else:
            min_gini = 2
            split_values = np.arange(column.min(),column.max(), (column.max() - column.min()) / 50)
            tmp = -1
            for i in split_values[15:35]:
                rhs = labels[column < i]
                lhs = labels[column >= i]
                tmp_gini = gini_impurity(rhs.value_counts()) + gini_impurity(lhs.value_counts())
                if tmp_gini <= min_gini:
                    min_gini = tmp_gini
                    tmp = i
            return tmp, min_gini
            
    def generate_split(self, data, labels):
        running_min = 2
        value = None
        clm = -1
        column = self.find_split(data[15], labels)
        for i in data.columns:
            val, tmp = self.find_split(data[i], labels)
            if tmp < running_min:
                clm = i
                value = val 
                running_min = tmp
                
        return clm, value

# %%
#Reading the training data
df_train = pd.read_csv("HW1_data/ann-train.data",sep=' ',header=None)

df_train.drop(columns=df_train.columns[-2:],inplace=True)
df_train_data, df_train_labels = df_train.drop(columns=df_train.columns[-1:]), df_train[21]
#Reading the test data
df_test = pd.read_csv("HW1_data/ann-test.data",sep=' ',header=None)

df_test.drop(columns=df_test.columns[-2:],inplace=True)
df_test_data, df_test_labels = df_test.drop(columns=df_test.columns[-1:]), df_test[21]

#Normalizing datasets
df_train_data_n = df_train_data.copy()
df_test_data_n = df_test_data.copy()
for column in df_train_data.columns:
    if df_train_data[column].dtype == 'float64':
        mean = df_train_data[column].mean()
        std = df_train_data[column].std()
        
        df_train_data_n[column] = (df_train_data_n[column] - mean) / std
        df_test_data_n[column] = (df_test_data_n[column] - mean) / std

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train_data, df_train_labels, test_size=0.4, random_state=55)
X_train_n, X_val_n, y_train_n, y_val_n = train_test_split(df_train_data_n, df_train_labels, test_size=0.4, random_state=55)

# %%
dn = decision_node(X_train, y_train)
dn.colm
# Out:
# decision_node created 0.14144973540220984
# decision_node created 0.13401237074244732
# decision_node created 0.1340683158289928
# decision_node created 0.13418034567901238
# decision_node created 0.13451755682016764
# decision_node created 0.13525400307512347
# decision_node created 0.1364028097659804
# decision_node created 0.1378664360828996
# decision_node created 0.13936167228524843
# decision_node created 0.1409513571620532
# decision_node created 0.14568000111118407
# decision_node created 0.14771859999351722
# leaf_node_created 0.0 11
# decision_node created 0.14847386414614128
# decision_node created 0.16267884814049594
# decision_node created 0.1456650774213364
# decision_node created 0.15013756782767462
# decision_node created 0.15511958161025075
# decision_node created 0.16174669724815094
# decision_node created 0.18824205862946553
# decision_node created 0.19235882069743548
# decision_node created 0.23631423283495423
# leaf_node_created 0.0 13
# decision_node created 0.20639875790760276
# decision_node created 0.20708984375000006
# decision_node created 0.2759453456863774
# decision_node created 0.27780861943024104
# decision_node created 0.14125
# decision_node created 0.09730440499671267
# leaf_node_created 0.0 37
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# decision_node created 0.2922130394857667
# decision_node created 0.29654278394185907
# decision_node created 0.3698224852071006
# decision_node created 0.39236111111111105
# decision_node created 0.38671817692796717
# decision_node created 0.46757637966429166
# decision_node created 0.3353057199211046
# decision_node created 0.06103515625
# decision_node created 0.06396130072561135
# decision_node created 0.06718192627824005
# decision_node created 0.10110803324099726
# decision_node created 0.13520408163265296
# leaf_node_created 0.0 9
# decision_node created 0.19390581717451527
# leaf_node_created 0.0 7
# decision_node created 0.29166666666666663
# leaf_node_created 0.0 10
# decision_node created 0.5
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# leaf_node_created 0.0 10
# leaf_node_created 0.0 20
# leaf_node_created 0.0 3
# leaf_node_created 0.0 3
# decision_node created 0.13265306122448983
# decision_node created 0.14201183431952646
# decision_node created 0.1527777777777779
# leaf_node_created 0.0 1
# decision_node created 0.16528925619834722
# leaf_node_created 0.0 1
# decision_node created 0.17999999999999994
# leaf_node_created 0.0 1
# decision_node created 0.19753086419753085
# leaf_node_created 0.0 1
# decision_node created 0.21875
# leaf_node_created 0.0 1
# leaf_node_created 0.0 7
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# decision_node created 0.42603550295857995
# leaf_node_created 0.0 4
# leaf_node_created 0.0 9
# decision_node created 0.20414201183431957
# decision_node created 0.1472
# leaf_node_created 0.0 46
# leaf_node_created 0.0 4
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# decision_node created 0.2728531855955679
# decision_node created 0.2790357925493061
# decision_node created 0.2922448979591835
# decision_node created 0.06444444444444453
# leaf_node_created 0.0 1
# decision_node created 0.06658739595719365
# decision_node created 0.07133058984910856
# decision_node created 0.07679999999999998
# decision_node created 0.07986111111111094
# leaf_node_created 0.0 3
# decision_node created 0.09070294784580502
# decision_node created 0.1049382716049383
# leaf_node_created 0.0 4
# decision_node created 0.13265306122448983
# leaf_node_created 0.0 13
# leaf_node_created 0.0 1
# leaf_node_created 0.0 3
# leaf_node_created 0.0 1
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# decision_node created 0.31999999999999984
# leaf_node_created 0.0 1
# leaf_node_created 0.0 4
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# decision_node created 0.17877746052094867
# decision_node created 0.09209157127991663
# decision_node created 0.09352324643912935
# leaf_node_created 0.0 12
# decision_node created 0.10314049586776863
# leaf_node_created 0.0 14
# decision_node created 0.1171875
# decision_node created 0.1472
# leaf_node_created 0.0 69
# leaf_node_created 0.0 6
# leaf_node_created 0.0 21
# leaf_node_created 0.0 2
# leaf_node_created 0.0 7
# decision_node created 0.20761245674740492
# leaf_node_created 0.0 15
# leaf_node_created 0.0 2
# leaf_node_created 0.0 3
# decision_node created 0.09937016931083331
# decision_node created 0.015563244905805407
# decision_node created 0.015624031248062442
# decision_node created 0.015685294255495252
# leaf_node_created 0.0 1
# decision_node created 0.015747039556563314
# decision_node created 0.016063203789604685
# decision_node created 0.016527777777777697
# leaf_node_created 0.0 9
# decision_node created 0.017166095088173128
# decision_node created 0.01793575070125497
# decision_node created 0.01877765548842114
# leaf_node_created 0.0 12
# decision_node created 0.019898487411934118
# leaf_node_created 0.0 62
# decision_node created 0.028770845543182766
# decision_node created 0.03570247933884296
# leaf_node_created 0.0 27
# decision_node created 0.04703149949194363
# leaf_node_created 0.0 22
# decision_node created 0.06342381080354742
# decision_node created 0.07133058984910856
# leaf_node_created 0.0 14
# decision_node created 0.09500000000000008
# leaf_node_created 0.0 38
# leaf_node_created 0.0 2
# leaf_node_created 0.0 7
# leaf_node_created 0.0 27
# leaf_node_created 0.0 10
# leaf_node_created 0.0 10
# leaf_node_created 0.0 7
# leaf_node_created 0.0 5
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# leaf_node_created 0.0 12
# decision_node created 0.16528925619834722
# leaf_node_created 0.0 10
# leaf_node_created 0.0 1
# decision_node created 0.09470041886723735
# decision_node created 0.08909764283785349
# decision_node created 0.025454658243814654
# decision_node created 0.025535900104058262
# decision_node created 0.025617662152679466
# decision_node created 0.025782766925909084
# decision_node created 0.026552857979370237
# decision_node created 0.027464313271604812
# leaf_node_created 0.0 17
# decision_node created 0.02916626952247381
# decision_node created 0.032219908371511785
# leaf_node_created 0.0 18
# decision_node created 0.03473772050689905
# decision_node created 0.049286025078121964
# decision_node created 0.08851895891134898
# decision_node created 0.058769513314967714
# leaf_node_created 0.0 32
# leaf_node_created 0.0 1
# decision_node created 0.10631001371742121
# decision_node created 0.11226451364859669
# decision_node created 0.15586419753086433
# decision_node created 0.12444444444444436
# leaf_node_created 0.0 14
# leaf_node_created 0.0 1
# decision_node created 0.17233560090702937
# leaf_node_created 0.0 2
# decision_node created 0.18836565096952906
# leaf_node_created 0.0 3
# decision_node created 0.21875
# leaf_node_created 0.0 3
# decision_node created 0.2603550295857988
# decision_node created 0.345679012345679
# leaf_node_created 0.0 2
# decision_node created 0.40816326530612246
# decision_node created 0.2777777777777777
# decision_node created 0.31999999999999984
# leaf_node_created 0.0 1
# leaf_node_created 0.0 4
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# leaf_node_created 0.0 4
# leaf_node_created 0.0 15
# leaf_node_created 0.0 3
# leaf_node_created 0.0 72
# leaf_node_created 0.0 68
# leaf_node_created 0.0 26
# leaf_node_created 0.0 10
# leaf_node_created 0.0 9
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# leaf_node_created 0.0 11
# leaf_node_created 0.0 1
# decision_node created 0.08869659275283936
# leaf_node_created 0.0 41
# leaf_node_created 0.0 2
# decision_node created 0.07502998493989477
# decision_node created 0.04189695966482443
# leaf_node_created 0.0 320
# leaf_node_created 0.0 7
# leaf_node_created 0.0 6
# decision_node created 0.09613843935266786
# decision_node created 0.05059875189745311
# decision_node created 0.05092058609936356
# decision_node created 0.05124653739612173
# decision_node created 0.05191111111111102
# decision_node created 0.05365041617122479
# decision_node created 0.05589772786087677
# leaf_node_created 0.0 8
# decision_node created 0.05920400909037937
# decision_node created 0.06444444444444453
# decision_node created 0.07535563244905807
# leaf_node_created 0.0 98
# leaf_node_created 0.0 4
# leaf_node_created 0.0 18
# leaf_node_created 0.0 11
# leaf_node_created 0.0 6
# leaf_node_created 0.0 5
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# leaf_node_created 0.0 1
# leaf_node_created 0.0 4
# decision_node created 0.0824910820451843
# decision_node created 0.08317580340264641
# decision_node created 0.08457984180436995
# decision_node created 0.08603197792386985
# decision_node created 0.08830589849108361
# decision_node created 0.09070294784580502
# decision_node created 0.09323337178008462
# decision_node created 0.09683465222823817
# decision_node created 0.10072430964237222
# leaf_node_created 0.0 8
# decision_node created 0.10951865873445099
# leaf_node_created 0.0 81
# leaf_node_created 0.0 5
# leaf_node_created 0.0 4
# leaf_node_created 0.0 4
# leaf_node_created 0.0 3
# leaf_node_created 0.0 3
# leaf_node_created 0.0 3
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# decision_node created 0.07328798185941032
# leaf_node_created 0.0 101
# leaf_node_created 0.0 4
# leaf_node_created 0.0 18
# decision_node created 0.039666278745758676
# leaf_node_created 0.0 5
# leaf_node_created 0.0 242
# decision_node created 0.045429962141698255
# decision_node created 0.046485260770975145
# decision_node created 0.04875000000000007
# decision_node created 0.05124653739612173
# decision_node created 0.054012345679012475
# decision_node created 0.05709342560553643
# decision_node created 0.060546875
# decision_node created 0.06658739595719365
# decision_node created 0.07679999999999998
# decision_node created 0.08317580340264641
# leaf_node_created 0.0 22
# leaf_node_created 0.0 1
# leaf_node_created 0.0 2
# leaf_node_created 0.0 4
# leaf_node_created 0.0 3
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# leaf_node_created 0.0 74
# leaf_node_created 0.0 26
# leaf_node_created 0.0 25
# leaf_node_created 0.0 25
# leaf_node_created 0.0 20
# leaf_node_created 0.0 13
# leaf_node_created 0.0 6
# leaf_node_created 0.0 2
# leaf_node_created 0.0 1
# leaf_node_created 0.0 10
# 16

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2263 entries, 91 to 461
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2263 non-null   float64
#  1   1       2263 non-null   int64
#  2   2       2263 non-null   int64
#  3   3       2263 non-null   int64
#  4   4       2263 non-null   int64
#  5   5       2263 non-null   int64
#  6   6       2263 non-null   int64
#  7   7       2263 non-null   int64
#  8   8       2263 non-null   int64
#  9   9       2263 non-null   int64
#  10  10      2263 non-null   int64
#  11  11      2263 non-null   int64
#  12  12      2263 non-null   int64
#  13  13      2263 non-null   int64
#  14  14      2263 non-null   int64
#  15  15      2263 non-null   int64
#  16  16      2263 non-null   float64
#  17  17      2263 non-null   float64
#  18  18      2263 non-null   float64
#  19  19      2263 non-null   float64
#  20  20      2263 non-null   float64
# dtypes: float64(6), int64(15)
# memory usage: 389.0 KB
